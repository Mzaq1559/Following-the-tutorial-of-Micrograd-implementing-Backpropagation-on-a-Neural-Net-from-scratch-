# %% [markdown]
# # Learning about derivative first using two and three variable function

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Defining a function randomly
def f(x):
    return 3*x**2 - 4*x + 5

# %%
f(3.0)
# Out:
# 20.0

# %%
xs = np.arange(-5, 5, 0.25)
ys = f(xs)
plt.plot(xs, ys)

# %%
# The value of derivative is 0.0 as the function has zero slope at x = 2/3
h = 0.00000001
x = 2/3
(f(x+h)-f(x))/h
# Out:
# 0.0

# %%
# lets get more complex
a = 2.0
b = -3.0
c = 10.0
d = a*b + c
print (d)
# Out:
# 4.0

# %%
#calculating derivative (the effect of small change in the value of given three variables on the value of d)
h = 0.0001

# inputs
a = 2.0
b = -3.0
c = 10.0

# for a
d1 = a*b + c
a += h
d2 = a*b + c

print('For "a"')
print('d1', d1)
print('d2', d2)
#print slope
print((d2-d1)/h)

# for b
d1 = a*b + c
b += h
d2 = a*b + c

print('For "b"')
print('d1', d1)
print('d2', d2)
#print slope
print((d2-d1)/h)

# for c
d1 = a*b + c
c += h
d2 = a*b + c

print('For "c"')
print('d1', d1)
print('d2', d2)
#print slope
print((d2-d1)/h)
# Out:
# For "a"
# d1 4.0
# d2 3.999699999999999
# -3.000000000010772
# For "b"
# d1 3.999699999999999
# d2 3.99990001
# 2.0001000000124947
# For "c"
# d1 3.99990001
# d2 4.00000001
# 0.9999999999976694

# %% [markdown]
# # Implementing the value object from micrograd

# %%
# Value Object
class Value:
    def __init__(self, data, _children=(), _op='', label=''):
        self.data = data
        self.grad = 0
        self._prev = set(_children)
        self._op = _op
        self.label = label

    def __repr__(self):
        return f"Value(data={self.data})"

    def __add__(self, other):
        out = Value(self.data + other.data, (self, other), '+')
        return out

    def __mul__(self, other):
        out = Value(self.data * other.data, (self,other), '*')
        return out

    # For implementing tanh (Hyperbolic Activation Function) from scratch on Value object
    def tanh(self):
        x = self.data
        t = (math.exp(2*x) - 1)/(math.exp(2*x) + 1)
        out = Value(t, (self,), "tanh")
        return out
    
# creating an instance of the value object

a = Value(2.0, label = 'a')
b = Value(-3.0, label = 'b')
c = Value(10.0, label = 'c')

# calculating the value of an expression
e = a*b; e.label = 'e'
d = e + c; d.label = 'd'
# d = (a.__mul__(b)),__add__(c)
f = Value(-2.0, label = 'f')
L = d * f; L.label = 'L'
L
# Out:
# Value(data=-8.0)

# %% [markdown]
# ### printing _prev of the result 'd' of the above expression

# %%
d._prev
# Out:
# {Value(data=-6.0), Value(data=10.0)}

# %% [markdown]
# ### printing _op of the result 'd' of the above expression

# %%
d._op
# Out:
# '+'

# %% [markdown]
# # For Visualization

# %%
from graphviz import Digraph

def trace(root):
    nodes, edges = set(), set()
    def build(v):
        if v not in nodes:
            nodes.add(v)
            for child in v._prev:
                edges.add((child, v))
                build(child)
    build(root)
    return nodes, edges

def draw_dot(root):
    dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'})

    nodes, edges = trace(root)
    for n in nodes:
        uid = str(id(n))
        dot.node(name=uid, label="{ %s | data %.4f | grad %.4f }" % (n.label, n.data, n.grad), shape='record')
        if n._op:
            dot.node(name=uid + n._op, label=n._op, shape='circle')
            dot.edge(uid + n._op, uid)

    for n1, n2 in edges:
        dot.edge(str(id(n1)), str(id(n2)) + n2._op)

    return dot

# %% [markdown]
# ## Visualizing d

# %%
draw_dot(L)

# %%
# Calculating gradient 
def grad():

    h = 0.001

    # Calculating L1
    a = Value(2.0, label = 'a')
    b = Value(-3.0, label = 'b')
    c = Value(10.0, label = 'c')
    e = a*b; e.label = 'e'
    d = e + c; d.label = 'd'
    f = Value(-2.0, label = 'f')
    L = d * f; L.label = 'L'
    L1 = L.data

    # Calculating L2
    a = Value(2.0, label = 'a')
    b = Value(-3.0, label = 'b')
    b.data += h
    c = Value(10.0, label = 'c')
    e = a*b; e.label = 'e'
    d = e + c; d.label = 'd'
    f = Value(-2.0, label = 'f')
    L = d * f; L.label = 'L'
    L2 = L.data

    # Calculating Gradient
    print((L2 - L1)/h)

grad()
# Out:
# -3.9999999999995595

# %% [markdown]
# ### Setting up calculated Gradients

# %%
# Gradient of a node is basically it's derivative with respect to L, it tells the degree and sign of affect a node has on the value of L

a.grad = 6.0
b.grad = -4.0
c.grad = -2.0
d.grad = -2.0
e.grad = -2.0
f.grad = 4.0

# %% [markdown]
# ### Calculating dL/da and dL/db

# %% [raw]
# we know:
# dL/de = -2
#
# we want:
# dL/da = (dL/de) * (de/da)
# dL/db = (dL/de) * (de/da)

# %% [markdown]
# ## Nudging all the values by a factor of gradient to increase the vamue of L

# %%
# incresing the value of of all leaf notes by 1% and checking the value of L
a.data += 0.01 * a.grad
b.data += 0.01 * b.grad
c.data += 0.01 * c.grad
f.data += 0.01 * f.grad

# Performing Operations
e = a * b
d = e + c
L = d * f

# Printing the value of L
print(L.data)
# Out:
# -7.286496

# %% [markdown]
# # Implementing Backpropagationg using a simple neuron

# %% [markdown]
# ### PLoting the tanh activation function from pyplot

# %%
plt.plot(np.arange(-5,5,0.2), np.tanh(np.arange(-5,5,0.2))); plt.grid()

# %% [markdown]
# ### Simple Neuron

# %%
# Inputs x1 and x2
x1 = Value(2.0, label='x1')
x2 = Value(0.0, label='x2')

# Weights w1 and w2
w1 = Value(-3.0, label='w1')
w2 = Value(1.0, label='w2')

# Bias
b = Value(6.8813735870195432, label='b')

# calculating product
x1w1 = x1*w1; x1w1.label='x1w1'
x2w2 = x2*w2; x2w2.label='x2w2'

# adding all the inputs multiplied by their weights
x1w1x2w2 = x1w1+x2w2; x1w1x2w2.label='x1*w1 + x2w2'

# computing expression
n = x1w1x2w2+b; n.label='n'

# calculating output
o = n.tanh(); o.label='o'

# %% [markdown]
# ### Visual representation without Activation function

# %%
draw_dot(n)

# %% [markdown]
# ### Visual representation of Neuron

# %%
draw_dot(o)

# %% [markdown]
# ### Gradients of Nodes

# %%
o.grad = 1
n.grad = 1 - o.data**2

# %%
# o = tanh(n)
# do/dn = 1 - o**2



1 - o.data**2
o
# Out:
# Value(data=0.9640275800758169)
